# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/jobindex_2021.csv')

# %%
# share BEFORE dropping NA titles
print(df.shape)

# remove NAN job titles
# df_nona = df.dropna(subset=['title'])

# shape AFTER dropping NA
# df_nona.shape
# Out:
# (4820088, 13)
# (4819424, 13)

# %% [markdown]
# # Select job titles (exact match)
#
# The select job titles are:
# - Kok
# - Journalist
# - Læge
# - Elektriker
# - Sygeplejerske
# - Ejendomsmægler
#
#
#
# PS: Excluded IT-sikkerhead because it's a category.

# %%
# Example kok & journalist

# df.head()

df[df.title.str.contains('Bo-', na=False)]

# df_nona
# Out:
#               id                                              title  \
# 0              1  Bo- og Aflastningstilbuddet Tankefuld søger ak...
# 1801        1802  Syddjurs Bo- og Aktivitetstilbud søger to pæda...
# 2363        2364  Engagerede og dygtige pædagoger eller lignende...
# 2371        2372  Pædagogiske medarbejdere til ansættelse 20 tim...
# 3625        3626  Pædagog til Bo- og Støttecenter Herning, Linde...
# ...          ...                                                ...
# 4809820  4810916  Synscenter Refsnæs Bo- og fritid afd. Birkehus...
# 4813601  4814697  Bo- og dagtilbuddet Musvågevej søger morgenfri...
# 4813905  4815001                             Pædagog til Bo-Horsens
# 4815477  4816573  Pædagog til Nørreskov Bo- og Aktivitetscenter ...
# 4817531  4818627  Bo- og beskæftigelsestilbud i Tinglev søger me...
#
#                                                    company         location  \
# 0                                        Svendborg Kommune        Svendborg
# 1801                                      Syddjurs Kommune         Ryomgård
# 2363                                    Københavns Kommune     København NV
# 2371                                    Københavns Kommune     København NV
# 3625                                       Herning Kommune          Herning
# ...                                                    ...              ...
# 4809820                                    Region Sjælland  Region Sjælland
# 4813601                                 Københavns Kommune            Valby
# 4813905  Region Midtjylland / Psykiatriske og Sociale i...          Horsens
# 4815477                                  Silkeborg Kommune        Silkeborg
# 4817531                                   Aabenraa Kommune          Kolding
#
#                                                description  \
# 0            Vi søger timelønnede medarbejdere - både u...
# 1801         Syddjurs Bo- og Aktivitetstilbud er en sam...
# 2363         Motiveres du af at bruge dit arbejde til a...
# 2371         Motiveres du af at bruge dit arbejde til a...
# 3625         Hvis du er uddannet pædagog og har lyst ti...
# ...                                                    ...
# 4809820          Synscenter Refsnæs Bo- og fritid afd.
# 4813601      Har du lyst og evner til at arbejde med me...
# 4813905      Egebjerg-kollegiet søger 1 pædagog 30 time...
# 4815477      Vi søger pr. 1. februar 2007 eller snarest...
# 4817531      Vi søger til beskæftigelsen Mads Clausensv...
#
#                         source        date  company_rating    type  \
# 0                    Jobcenter  2021-03-04             NaN  unpaid
# 1801                 Jobcenter  2021-02-16             NaN  unpaid
# 2363                 Jobcenter  2021-02-15             NaN  unpaid
# 2371                 Jobcenter  2021-02-15             NaN  unpaid
# 3625                 Jobcenter  2021-02-11             NaN  unpaid
# ...                        ...         ...             ...     ...
# 4809820        Region Sjælland  2007-01-16             NaN  unpaid
# 4813601  Offentlige Stillinger  2007-01-12             NaN  unpaid
# 4813905  Offentlige Stillinger  2007-01-12             NaN  unpaid
# 4815477         AF-Midtjylland  2007-01-11             NaN  unpaid
# 4817531               Jobzonen  2007-01-09             NaN  unpaid
#
#         description_img  company_rating_amount  ratings_link  \
# 0                   NaN                    NaN           NaN
# 1801                NaN                    NaN           NaN
# 2363                NaN                    NaN           NaN
# 2371                NaN                    NaN           NaN
# 3625                NaN                    NaN           NaN
# ...                 ...                    ...           ...
# 4809820             NaN                    NaN           NaN
# 4813601             NaN                    NaN           NaN
# 4813905             NaN                    NaN           NaN
# 4815477             NaN                    NaN           NaN
# 4817531             NaN                    NaN           NaN
#
#                                   link
# 0        /bruger/dine-job/r9423946/gem
# 1801     /bruger/dine-job/r9391591/gem
# 2363     /bruger/dine-job/r9390115/gem
# 2371     /bruger/dine-job/r9390263/gem
# 3625     /bruger/dine-job/r9382564/gem
# ...                                ...
# 4809820  /bruger/dine-job/r1595534/gem
# 4813601  /bruger/dine-job/r1588519/gem
# 4813905  /bruger/dine-job/r1588349/gem
# 4815477  /bruger/dine-job/r1585534/gem
# 4817531  /bruger/dine-job/r1580661/gem
#
# [2203 rows x 13 columns]

# %% [markdown]
# # Normalize

# %% [markdown]
# # Display evolution over time
