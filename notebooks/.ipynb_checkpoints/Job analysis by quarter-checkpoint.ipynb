# %%
# 1. Filter professions
## 1.a Partial match job search
## 1.b Lemmatize
## 1.c Search
# 2. Convert to quarter results
# 3. Display tables

# %%
import pandas as pd

# %%
# jobindex
df_raw = pd.read_csv('../data/jobindex_2021.csv', engine='python')

# %%
df_raw.head()
# Out:
#   id                                              title  \
# 0  1  Bo- og Aflastningstilbuddet Tankefuld søger ak...
# 1  2          Billigblomst Aalborg søger kasseassistent
# 2  3  Billigblomst Næstved søger to kompetente kasse...
# 3  4        BILLIGBOMST RANDERS SØGER BUTIKSASSISTENTER
# 4  5                               Studentermedarbejder
#
#                     company    location  \
# 0         Svendborg Kommune   Svendborg
# 1  BilligBlomst Aalborg ApS  Aalborg SV
# 2  BilligBlomst Næstved ApS  Holmegaard
# 3  BilligBlomst Randers ApS  Randers SØ
# 4  Dansk Firmaidrætsforbund      Nyborg
#
#                                          description  \
# 0      Vi søger timelønnede medarbejdere - både u...
# 1      Har du solid erfaringen indenfor butiksver...
# 2      Har du solid erfaringen indenfor butiksver...
# 3      Billigblomst søger 2 nye medarbejdere til ...
# 4                                                NaN
#
# ...

# %%
# Partial match job search

# %%
# def find_results(job_title):
#     df[df['A'].str.contains(job_title)]

# 'Læge'

# df_raw['title'].dropna(inplace=True)

# df_raw[df_raw['title'].str.contains('Læge')]

# %%
df_raw.head()
# Out:
#   id                                              title  \
# 0  1  Bo- og Aflastningstilbuddet Tankefuld søger ak...
# 1  2          Billigblomst Aalborg søger kasseassistent
# 2  3  Billigblomst Næstved søger to kompetente kasse...
# 3  4        BILLIGBOMST RANDERS SØGER BUTIKSASSISTENTER
# 4  5                               Studentermedarbejder
#
#                     company    location  \
# 0         Svendborg Kommune   Svendborg
# 1  BilligBlomst Aalborg ApS  Aalborg SV
# 2  BilligBlomst Næstved ApS  Holmegaard
# 3  BilligBlomst Randers ApS  Randers SØ
# 4  Dansk Firmaidrætsforbund      Nyborg
#
#                                          description  \
# 0      Vi søger timelønnede medarbejdere - både u...
# 1      Har du solid erfaringen indenfor butiksver...
# 2      Har du solid erfaringen indenfor butiksver...
# 3      Billigblomst søger 2 nye medarbejdere til ...
# 4                                                NaN
#
# ...

# %%
df_raw[df_raw['title'].str.contains('Læge', na=False)].head(50)
# Out:
#           id                                              title  \
# 1916    1917  Studentermedhjælper til Lægemiddelstyrelsens e...
# 2145    2146  Lægesekretær ved Idrætsklinikken, Ortopædkirur...
# 2386    2387                Lægesekretær / SOSU til lægepraksis
# 2560    2561  Lægesekretær med lyst til at deltage i opbygni...
# 2807    2808  Lægesekretær til Arytmi Klinikken ved Hjertesy...
# 2808    2809  Lægesekretær til Plastik- og Brystkirurgisk Af...
# 2809    2810  Lægesekretær/sundhedsservicesekretær til Recep...
# 3117    3118                 Lægesekretær til geriatrisk område
# 4071    4072          Læger fra hele landet søges til psykiatri
# 4091    4092  Lægesekretær søges til 1-årigt vikariat på H. ...
# 4387    4388  Læger søges til vaccinationsprogram Region Sjæ...
# 4831    4832  Lægesekretær med lyst til udfordrende opgaver ...
# 5103    5104  Fagligt stærke akademiske sagsbehandlere til e...
# 5104    5105  Special- eller chefkonsulent til nyoprettet ju...
# ...

# %%
# There are a lot of false positives

# %%
import spacy
