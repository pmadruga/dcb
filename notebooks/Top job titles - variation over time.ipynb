# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/jobindex_2021.csv')

# %%
# share BEFORE dropping NA titles
print(df.shape)

# lower case titles
df['title'] = df['title'].str.lower()

# remove NAN job titles
# df_nona = df.dropna(subset=['title'])

# shape AFTER dropping NA
# df_nona.shape
# Out:
# (4820088, 13)

# %% [markdown]
# # Select job titles (exact match)
#
# The select job titles are:
# - Kok
# - Journalist
# - Læge
# - Elektriker
# - Sygeplejerske
# - Ejendomsmægler
#
#
#
# PS: Excluded IT-sikkerhead because it's a category.

# %%
# Example kok & journalist

# df.head()

df[df.title.str.contains('kok', na=False)]

# df_nona
# Out:
#               id                                          title  \
# 89            90            kragerup gods søger 2 udlærte kokke
# 655          656                        erfaren kok/cater søges
# 785          786          flyvefisken risskov søger faglært kok
# 1018        1019                                      kok søges
# 1271        1272  kok søges til restaurant nordstjernen blokhus
# ...          ...                                            ...
# 4819750  4820846                     kok til hotel koldingfjord
# 4819751  4820847                    kok søges til hotel randers
# 4819903  4820999                               slagtersvend/kok
# 4819913  4821009                kok eller køkkenassistent søges
# 4820020  4821116                          selvstændig kok søges
#
#                                                  company            location  \
# 89                                         Kragerup Gods          Ruds Vedby
# ...

# %% [markdown]
# # Normalize

# %% [markdown]
# # Display evolution over time
